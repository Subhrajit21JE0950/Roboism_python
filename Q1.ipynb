# %%
def func(lis,st):
  if(st=="asc"):
    lis.sort()
  elif(st=="desc"):
    lis.sort(reverse=True)
  else:
    return lis

  return lis

# %%
l=[3,2,7]
l=func(l,"de")
l
# Out:
# [3, 2, 7]

# %%
l=[4,8,2]
l=func(l,"asc")
l
# Out:
# [2, 4, 8]
