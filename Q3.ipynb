# %%
def oper(n1,o,n2):
  t=0
  if(o=="+"):
    t=n1+n2
  if(o=="-"):
    t=n1-n2
  if(o=="*"):
    t=n1*n2
  if(o=="/"):
    t=n1/n2
  return t

# %%
a,b=6,4
print(oper(a,"*",b))
# Out:
# 24

# %%
a,b=6,4
print(oper(a,"+",b))
# Out:
# 10
