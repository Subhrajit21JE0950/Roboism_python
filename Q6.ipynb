# %%
def check(n):
  if(n==2): return True
  for i in range(2,n):
    if(n%i==0):
      return False
  return True

# %%
a,b=23,30
for i in range(a,b+1):
  if(check(i)): print(i)
# Out:
# 23
# 29

# %%
a,b=3,20
for i in range(a,b+1):
  if(check(i)): print(i)
# Out:
# 3
# 5
# 7
# 11
# 13
# 17
# 19
