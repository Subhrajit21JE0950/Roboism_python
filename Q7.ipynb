# %%
def higfre(lis):
  l=[]
  for i in range(len(lis)):
    l.append(lis.count(lis[i]))
  
  index=l.index(max(l))
  return lis[index]

# %%
l=[1,2,3,2,2,3,3,3,4]
print(higfre(l))
# Out:
# 3

# %%
l=[2,3,1,8,3,6,7,8,8]
print(higfre(l))
# Out:
# 8
