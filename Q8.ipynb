# %%
def sum(s):
  sum=0
  for i in range(len(s)):
    if(s[i].isdigit()):
      sum=sum+int(s[i])

  return sum

# %%
st="h20 15 wa73r"
print(sum(st))
# Out:
# 18

# %%
st="uiqgfd934bjd"
print(sum(st))
# Out:
# 16
