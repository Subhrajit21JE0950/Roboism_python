# %%
def find(do):
  t=0
  for i in range(len(do)):
    for j in range(i+1,len(do)):
      if(do[i]==do[j]):
        t=do[i]
        return t

# %%
ar=[1,2,3,2,5,2,6]
print(find(ar))
# Out:
# 2

# %%
ar=[1,2,3,4,5,4,6]
print(find(ar))
# Out:
# 4
